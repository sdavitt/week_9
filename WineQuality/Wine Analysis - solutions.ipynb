# %% [markdown]
# # Answer these questions:
#
# * number of samples in each dataset
# * number of columns in each dataset
# * features with missing values
# * duplicate rows in the white wine dataset
# * number of unique values for quality in each dataset
# * mean density of the red wine dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_red = pd.read_csv('./winequality-red.csv', sep=';')
df_white = pd.read_csv('./winequality-white.csv', sep=';')

# %%
df_red.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
df_white.tail()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 4893                 24.0                  92.0  0.99114  3.27       0.50
# 4894                 57.0                 168.0  0.99490  3.15       0.46
# 4895                 30.0                 111.0  0.99254  2.99       0.46
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 4897                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality
# 4893     11.2        6
# ...

# %%
df_red.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
df_white.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         4898 non-null   float64
#  1   volatile acidity      4898 non-null   float64
#  2   citric acid           4898 non-null   float64
#  3   residual sugar        4898 non-null   float64
#  4   chlorides             4898 non-null   float64
#  5   free sulfur dioxide   4898 non-null   float64
#  6   total sulfur dioxide  4898 non-null   float64
#  7   density               4898 non-null   float64
#  8   pH                    4898 non-null   float64
#  9   sulphates             4898 non-null   float64
#  10  alcohol               4898 non-null   float64
#  11  quality               4898 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB

# %%
df_red.duplicated().sum()
# Out:
# 240

# %%
df_white.duplicated().sum()
# Out:
# 937

# %%
df_white
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
len(df_red)
# Out:
# 1599

# %%
color_red = np.repeat("red", len(df_red))
color_white = np.repeat("white", len(df_white))

df_red['color'] = color_red
df_white['color'] = color_white

# %%
# df_red.head()
df_white.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality  color
# 0      8.8        6  white
# 1      9.5        6  white
# ...

# %%
df_wine = df_red.append(df_white, ignore_index=True)

# %%
df_wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality color
# 0      9.4        5   red
# 1      9.8        5   red
# ...

# %%
df_wine.to_csv('./winequality_edited.csv', index=False)
df_wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
df_wine.groupby(['color']).quality.mean()
# Out:
# color
# red      5.636023
# white    5.877909
# Name: quality, dtype: float64

# %%
df_wine.describe().pH
# Out:
# count    6497.000000
# mean        3.218501
# std         0.160787
# min         2.720000
# 25%         3.110000
# 50%         3.210000
# 75%         3.320000
# max         4.010000
# Name: pH, dtype: float64

# %%
# Bin edges that will be used to "cut" the data into groups
bin_edges = [2.72, 3.11, 3.21, 3.32, 4.01]

# %%
# Labels for the four acidity level groups
bin_names = ['low', 'moderate', 'medium', 'high']

# %%
# Creates acidity_levels column
df_wine['acidity_levels'] = pd.cut(df_wine['pH'], bin_edges, labels=bin_names)

# Checks for successful creation of this column
df_wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality color acidity_levels
# 0      9.4        5   red           high
# ...

# %%
df_wine.groupby(['acidity_levels']).quality.mean()
# Out:
# acidity_levels
# low         5.783343
# moderate    5.784540
# medium      5.850832
# high        5.859593
# Name: quality, dtype: float64

# %%
df_wine.to_csv('./winequality_edited_v2.csv', index=False)

# %%
# get the median amount of alcohol content
df_wine.alcohol.median()
# Out:
# 10.3

# %%
# df_wine[df_wine['quality'] > 5]
df_wine.query('quality > 5')
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 3              11.2              0.28         0.56             1.9      0.075
# 7               7.3              0.65         0.00             1.2      0.065
# 8               7.8              0.58         0.02             2.0      0.073
# 16              8.5              0.28         0.56             1.8      0.092
# 19              7.9              0.32         0.51             1.8      0.341
# ...             ...               ...          ...             ...        ...
# 6490            5.7              0.21         0.32             0.9      0.038
# 6492            6.2              0.21         0.29             1.6      0.039
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
df_wine.alcohol.count()
# Out:
# 6497

# %%
# select samples with alcohol content less than the median
low_alcohol = df_wine.query(f'alcohol < {df_wine.alcohol.median()}')

# select samples with alcohol content greater than or equal to the median
high_alcohol = df_wine.query(f'alcohol >= {df_wine.alcohol.median()}')

# ensure these queries included each sample exactly once
num_samples = df_wine.shape[0]
num_samples == low_alcohol.quality.count() + high_alchohol.quality.count()
# Out:
# True

# %%
# get mean quality rating for the low alcohol and high alcohol groups
print(f"Low alchohol wines, quality mean: {low_alcohol.quality.mean()}")
print(f"High alchohol wines, quality mean: {high_alcohol.quality.mean()}")
# Out:
# Low alchohol wines, quality mean: 5.475920679886686
# High alchohol wines, quality mean: 6.146084337349397

# %%
# get the median amount of residual sugar
df_wine['residual sugar'].median()
# Out:
# 3.0

# %%
# select samples with residual sugar less than the median
low_sugar = df_wine[df_wine['residual sugar'] < df_wine['residual sugar'].median()]

# select samples with residual sugar greater than or equal to the median
high_sugar = df_wine[df_wine['residual sugar'] >= df_wine['residual sugar'].median()]

# ensure these queries included each sample exactly once
num_samples == low_sugar['quality'].count() + high_sugar['quality'].count()
# Out:
# True

# %%
# get mean quality rating for the low sugar and high sugar groups
print(f"Low sugar wines, quality mean: {low_sugar.quality.mean()}")
print(f"High sugar wines, quality mean: {high_sugar.quality.mean()}")
# Out:
# Low sugar wines, quality mean: 5.808800743724822
# High sugar wines, quality mean: 5.82782874617737

# %% [markdown]
# ## Which types of wines&mdash;red or white&mdash;are associated with higher quality?

# %%
wines = ["red", "gray"]
wine_averages = df_wine.groupby('color')['quality'].mean()
wine_averages.plot(kind="bar", color=wines)
plt.title("Average Wine Quality by Color", fontsize=16)
plt.xlabel('Colors', fontsize=16)
plt.ylabel("Quality", fontsize=16);
# plt.show()
