# %% [markdown]
# # Is Global Warming a Thing?

# %% [markdown]
# #### This is an attempt  to find comparisons between the assumption that global warming is real or not.
# #### To decide, you'll conduct a study on a 200-year trend from 1813-2013. These samples should be sufficient enough to determine the validity of Global Warming.
#
# <strong>Note</strong>: to complete this data report, you will need to calculate moving average of weather over a period of 200 years. Click <a href="https://www.portent.com/blog/analytics/rolling-averages-math-moron.htm">here</a> to learn how to calculate moving averages.
#
# <strong>Moving averages are also known as rolling averages</strong>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Retrieving Data

# %%
df_global = pd.read_csv('weather_global.csv')
df_chicago = pd.read_csv('weather_chicago.csv')

# %%
df_global.head()
# Out:
#    year  avg_temp
# 0  1750      8.72
# 1  1751      7.98
# 2  1752      5.78
# 3  1753      8.39
# 4  1754      8.47

# %%
df_chicago.head()
# Out:
#    year     city        country  avg_temp
# 0  1743  Chicago  United States      5.44
# 1  1744  Chicago  United States     11.73
# 2  1745  Chicago  United States      1.80
# 3  1746  Chicago  United States       NaN
# 4  1747  Chicago  United States       NaN

# %% [markdown]
# ## Clean Data

# %% [markdown]
# #### Drop 'city' and 'country' columns

# %%
df_chicago.drop(['city', 'country'], axis=1, inplace=True)

# %%
df_chicago.head(1)
# Out:
#    year  avg_temp
# 0  1743      5.44

# %%
df_chicago.columns
# Out:
# Index(['year', 'avg_temp'], dtype='object')

# %% [markdown]
# #### Check for null values

# %%
# df_chicago.isnull().sum()
df_chicago.isna().sum()
# Out:
# year        0
# avg_temp    4
# dtype: int64

# %%
df_global.isnull().sum()
# Out:
# year        0
# avg_temp    0
# dtype: int64

# %% [markdown]
# #### Remove null values

# %%
df_chicago.dropna(inplace=True)

# %%
df_chicago.isna().sum()
# Out:
# year        0
# avg_temp    0
# dtype: int64

# %%
df_chicago.head(10)
# Out:
#     year  avg_temp
# 0   1743      5.44
# 1   1744     11.73
# 2   1745      1.80
# 7   1750     10.49
# 8   1751     11.19
# 9   1752      4.50
# 10  1753     10.04
# 11  1754     10.64
# 12  1755      7.41
# 13  1756     11.15

# %%
# for i in range(len(df_chicago)):
#     print(df_chicago.iloc[i])

# %% [markdown]
# #### Convert all temps to Fahrenheit

# %%
df_chicago.avg_temp = df_chicago.avg_temp.apply(lambda temp: round(temp * (9/5) + 32, 2))
df_global.avg_temp = df_global.avg_temp.apply(lambda temp: round(temp * (9/5) + 32, 2))

# %%
df_chicago
# Out:
#      year  avg_temp
# 0    1743     41.79
# 1    1744     53.11
# 2    1745     35.24
# 7    1750     50.88
# 8    1751     52.14
# ..    ...       ...
# 266  2009     50.54
# 267  2010     53.28
# 268  2011     52.18
# 269  2012     55.08
# 270  2013     52.86
#
# [267 rows x 2 columns]

# %%
df_global
# Out:
#      year  avg_temp
# 0    1750     47.70
# 1    1751     46.36
# 2    1752     42.40
# 3    1753     47.10
# 4    1754     47.25
# ..    ...       ...
# 261  2011     49.14
# 262  2012     49.12
# 263  2013     49.30
# 264  2014     49.23
# 265  2015     49.69
#
# [266 rows x 2 columns]

# %% [markdown]
# #### Trim results to same time period

# %%
df_chicago = df_chicago.query('year >= 1764 and year <= 2013')
df_chicago
# Out:
#      year  avg_temp
# 21   1764     51.13
# 22   1765     49.60
# 23   1766     50.88
# 24   1767     48.94
# 25   1768     48.11
# ..    ...       ...
# 266  2009     50.54
# 267  2010     53.28
# 268  2011     52.18
# 269  2012     55.08
# 270  2013     52.86
#
# [250 rows x 2 columns]

# %%
df_global = df_global.query('year >= 1764 and year <= 2013')
df_global
# Out:
#      year  avg_temp
# 14   1764     47.12
# 15   1765     46.85
# 16   1766     47.14
# 17   1767     46.80
# 18   1768     44.20
# ..    ...       ...
# 259  2009     49.12
# 260  2010     49.46
# 261  2011     49.14
# 262  2012     49.12
# 263  2013     49.30
#
# [250 rows x 2 columns]

# %% [markdown]
# #### Save to new CSVs

# %%
df_chicago.reset_index(drop=True, inplace=True)
df_chicago.to_csv('clean_chicago.csv')

# %%
df_global.reset_index(drop=True, inplace=True)
df_global.to_csv('clean_global.csv')

# %%
df_chicago.head()
# Out:
#    year  avg_temp
# 0  1764     51.13
# 1  1765     49.60
# 2  1766     50.88
# 3  1767     48.94
# 4  1768     48.11

# %%
df_global.head()
# Out:
#    year  avg_temp
# 0  1764     47.12
# 1  1765     46.85
# 2  1766     47.14
# 3  1767     46.80
# 4  1768     44.20

# %% [markdown]
# ## Global 50-year moving average

# %% [markdown]
# #### Calculated 50-year moving average starting from 1764. First calculated average starts at 1813

# %%
# DON'T RUN THIS CELL
# THESE ARE THE NUMBERS YOU SHOULD BE GETTING

# %% [markdown]
# #### Create a new column that holds rolling averages

# %%
df_chicago.avg_temp.rolling(50).mean()
# Out:
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#         ...
# 245    51.0980
# 246    51.1596
# 247    51.1824
# 248    51.2844
# 249    51.3456
# Name: avg_temp, Length: 250, dtype: float64

# %%
df_chicago['ra_50'] = round(df_chicago.avg_temp.rolling(50).mean(), 2)
# Out:
# <ipython-input-24-6b86b1b8f60e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_chicago['ra_50'] = round(df_chicago.avg_temp.rolling(50).mean(), 2)

# %%
df_global['ra_50'] = round(df_global.avg_temp.rolling(50).mean(), 2)
# Out:
# <ipython-input-25-b9b09a7e0529>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_global['ra_50'] = round(df_global.avg_temp.rolling(50).mean(), 2)

# %%
df_chicago[df_chicago.ra_50.notnull()].head()
# Out:
#     year  avg_temp  ra_50
# 49  1813     49.41  49.91
# 50  1814     49.19  49.87
# 51  1815     47.95  49.84
# 52  1816     46.89  49.76
# 53  1817     47.37  49.73

# %%
df_global[df_global.ra_50.notnull()].head()
# Out:
#     year  avg_temp  ra_50
# 49  1813     45.93  46.69
# 50  1814     45.66  46.66
# 51  1815     45.03  46.62
# 52  1816     44.49  46.57
# 53  1817     44.56  46.53

# %%
# DO NOT RUN THIS CELL! YOU'LL LOSE THE VISUAL REPRESENTATION IF YOU DO!

# Create a graph that plots two scatter plots and compares the global temperature by year (yellow) vs the 
# rolling average by year (green)

# %%
year_range = range(1813, 2014, 50)
year_labels = ['1813', '1863', '1913', '1963', '2013']

# %% [markdown]
# #### Global

# %%
plt.figure(figsize=(13, 9))

plt.plot(df_global.year, df_global.avg_temp, color='orange')
plt.plot(df_global.year, df_global.ra_50, color='green')
plt.xticks(year_range, year_labels)
plt.xlim(int(year_labels[0]), int(year_labels[-1]))

plt.title('Global Temperatures (1813-2013)', fontsize=18)
plt.ylabel('Temperature (Fahrenheit)', fontsize=14)
plt.xlabel('Year', fontsize=14)
plt.grid(True)
plt.legend(['Average', 'Rolling Average'], loc='best', prop={'size': 15});

# %% [markdown]
# ## Chicago 50-year moving average

# %% [markdown]
# #### Calculated 50-year moving average starting from 1764. First calculated average starts at 1813

# %%
# DON'T RUN THIS CELL
# THESE ARE THE NUMBERS YOU SHOULD BE GETTING

# %% [markdown]
# #### Create new column that holds rolling averages

# %%
df_chicago[df_chicago.ra_50.notnull()]
# Out:
#      year  avg_temp  ra_50
# 49   1813     49.41  49.91
# 50   1814     49.19  49.87
# 51   1815     47.95  49.84
# 52   1816     46.89  49.76
# 53   1817     47.37  49.73
# ..    ...       ...    ...
# 245  2009     50.54  51.10
# 246  2010     53.28  51.16
# 247  2011     52.18  51.18
# 248  2012     55.08  51.28
# 249  2013     52.86  51.35
#
# [201 rows x 3 columns]

# %%
plt.figure(figsize=(13, 9))

plt.plot(df_chicago.year, df_chicago.avg_temp, color='orange')
plt.plot(df_chicago.year, df_chicago.ra_50, color='green')
plt.xticks(year_range, year_labels)
plt.xlim(int(year_labels[0]), int(year_labels[-1]))

plt.title('Chicago Temperatures (1813-2013)', fontsize=18)
plt.ylabel('Temperature (Fahrenheit)', fontsize=14)
plt.xlabel('Year', fontsize=14)
plt.grid(True)
plt.legend(['Average', 'Rolling Average'], loc='best', prop={'size': 15});

# %%
# DO NOT RUN THIS CELL! YOU'LL LOSE THE VISUAL REPRESENTATION IF YOU DO!

# Create a graph that plots two scatter plots and compares the local temperature (for Chicago) by year (yellow) vs the 
# rolling average by year (green)

# %% [markdown]
# ## Conclusions
# #### 1) The 50-yr rolling average temperature in Chicago flips from decreasing to increasing around the turn of the 20th century.
# #### 2) The 50-yr rolling average temperature in Chicago is at an all-time high.
# #### 3) The 50-yr rolling average temperature in Chicago seems to be more consistent and stable than the global 50-yr rolling avg temp.
# #### 4) The 50-yr rolling average temperature in Chicago is increasing at a much slower pace than the global 50-yr rolling avg temp.
